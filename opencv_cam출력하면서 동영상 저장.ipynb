# %%
import cv2

# %%
video = cv2.VideoCapture(0)

# %%
# cam 재생은 되나 save 가 안됨
while video.isOpened():
    ret, img = video.read()
    if not ret:
        print('no frame')
        break

    cv2.imshowh('record video', img)
    
    w = round(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = round(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = video.get(cv2.CAP_PROP_FPS)
# avi    
#     fourcc = cv2.VideoWriter_fourcc(*'DIVX')    #  'D','I','V'
#     delay = round(1000/fps)    
#     out = cv2.VideoWriter('./saved.avi',fourcc,fps,(w,h))
# mp4

    fourcc = cv2.VideoWriter_fourcc(*'MP4V') 
    delay = round(1000/fps)    
    out = cv2.VideoWriter('./saved.mp4',fourcc,fps,(w,h))
    
    if not out.isOpened():
        print('File open failed!')
        video.release()
        break
    
    if cv2.waitKey(1) & 0xff == 27:
        break

video.release()
cv2.destroyAllWindows()

# %%
# 동작함  사용
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'DIVX')
out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        # write the flipped frame
        out.write(frame)
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
# 동작함
video = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'DIVX')
out = cv2.VideoWriter('saved.avi',fourcc,20.0,(640,480))
while video.isOpened():
    ret, frame = video.read();
    if not ret:
        print('error open cam')
        break
    out.write(frame)
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xff == 27:  # esc
        break
video.release()
out.release()
cv2.destroyAllWindows()

# %%
# !pip install -r ./yolov5/requirements.txt
# Out:
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
#   Using cached thop-0.0.31.post2005241907-py3-none-any.whl (8.7 kB)
# ...

# %%
# !python ./yolov5/detect.py --weights ./yolov5/runs/train/exp2/weights/best.pt --source ./output.avi
# Out:
# detect: weights=['./yolov5/runs/train/exp2/weights/best.pt'], source=./output.avi, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2021-12-31 torch 1.10.1+cpu CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/279) C:\Users\User\output.avi: 480x640 Done. (0.201s)
# video 1/1 (2/279) C:\Users\User\output.avi: 480x640 Done. (0.167s)
# video 1/1 (3/279) C:\Users\User\output.avi: 480x640 Done. (0.172s)
# video 1/1 (4/279) C:\Users\User\output.avi: 480x640 Done. (0.154s)
# video 1/1 (5/279) C:\Users\User\output.avi: 480x640 Done. (0.174s)
# video 1/1 (6/279) C:\Users\User\output.avi: 480x640 Done. (0.153s)
# ...

# %%
import cv2
filepath = './yolov5/runs/detect/exp/output.avi'
cap = cv2.VideoCapture(filepath)
w = round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
    
while cap.isOpened():    
    ret, frame = cap.read()
    if not ret:
        print("fail open video")
        break
        
#     gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)     
    delay = round(1000/fps)    
    cv2.waitKey(delay) 
    cv2.imshow('detected',frame)
    
    if cv2.waitKey(1) & 0xff == 0:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# fail open video

# %%
import cv2
filepath = './yolov5/runs/detect/exp/output.avi'
names = [0, filepath]
window_titles = ['real','detected']
print('111111111111')
cap = [cv2.VideoCapture(i) for i in names]
print('222222222222')

ret = [None]*len(names)
frames = [None]*len(names)
isOnce = True
while True:
    for i , c in enumerate(cap):
        ret[i], frames[i] = c.read()    
    # detect.py를 호출한다 한번만
    if(isOnce):        
        # !python ./yolov5/detect.py --weights ./yolov5/runs/train/exp2/weights/best.pt --source ./output.avi        
        isOnce = False    
    
    for i, f in enumerate(frames):        
        if ret[i]:
            cv2.imshow(window_titles[i],f)
    if cv2.waitKey(1) & 0xff == 0:  #esc
        break

for c in cap:
    c.release()
cv2.destroyAllWindows()
# Out:
# 111111111111
# 222222222222
# detect: weights=['./yolov5/runs/train/exp2/weights/best.pt'], source=./output.avi, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2021-12-31 torch 1.10.1+cpu CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/279) C:\Users\User\output.avi: 480x640 Done. (0.189s)
# video 1/1 (2/279) C:\Users\User\output.avi: 480x640 Done. (0.195s)
# video 1/1 (3/279) C:\Users\User\output.avi: 480x640 Done. (0.220s)
# video 1/1 (4/279) C:\Users\User\output.avi: 480x640 Done. (0.200s)
# video 1/1 (5/279) C:\Users\User\output.avi: 480x640 Done. (0.195s)
# ...
